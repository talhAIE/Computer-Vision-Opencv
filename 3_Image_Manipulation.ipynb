# %%
#importing necessary libraries
import cv2
from IPython.display import Image
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# #Load image and convert it into from BGR into RGB to show it original with matplotlib

# %%
img=cv2.imread('/content/perc.jpg',1)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# #Basic image operations we can apply before display

# %%
#convert to grayscale
img=cv2.imread('/content/perc.jpg',0)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#Resize
img=cv2.imread('/content/perc.jpg',1)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img=cv2.resize(img,(400,400))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# #Negative of image

# %%
#Resize
img=cv2.imread('/content/perc.jpg',0)
plt.imshow(img,cmap='gray')
plt.title('Original GrayScale image')
plt.axis('off')
plt.show()

# %%
#negative of image
neg_img=255-img
plt.imshow(neg_img,cmap='gray')
plt.title('Negative GrayScale image')
plt.axis('off')
plt.show()

# %%
#Apply binary Threshold
_,binary_img=cv2.threshold(img,200,255,cv2.THRESH_BINARY)
plt.imshow(binary_img,cmap='gray')
plt.title('Binary image')
plt.axis('off')
plt.show()

# %%
#Apply binary Threshold
_,binary_img=cv2.threshold(img,240,255,cv2.THRESH_BINARY)
plt.imshow(binary_img,cmap='gray')
plt.title('Binary image')
plt.axis('off')
plt.show()

# %% [markdown]
# #Accessing individual Pixels
#
# ![image.png](data:image/png;base64,...)

# %%
image=cv2.imread('/content/pix.png',0)
plt.imshow(image,cmap='gray')

# %%
image[0,0]
# Out:
# 211

# %%
image[0,5]
# Out:
# 255

# %% [markdown]
# #Modify Image Pixels

# %%
#copy image
imagec=image.copy()

# %%
imagec[0,4]=200
imagec[0,5]=200
imagec[0,6]=200
imagec[0,7]=200
imagec[0,8]=200

# %%
for i in range(150):
  imagec[50,i]=0

# %%
plt.imshow(imagec,cmap='gray')

# %% [markdown]
# #Cropping Images

# %%
imgcrop=cv2.imread('/content/perc.jpg',cv2.IMREAD_COLOR)
imgcroprgb=imgcrop[:,:,::-1]
plt.imshow(imgcroprgb)

# %%
imgcropped=imgcroprgb[25:100,80:200]
plt.imshow(imgcropped)

# %% [markdown]
# # Resizing Images
#
# The function **`resize`** resizes the image `src` down to or up to the specified size. The size and type are derived from the `src`,`dsize`,`fx`, and `fy`.
#
# ### <font style="color:rgb(8,133,37)">Function Syntax </font>
#
# ``` python
# dst = resize( src, dsize[, dst[, fx[, fy[, interpolation]]]] )
# ```
#
# `dst`: output image; it has the size dsize (when it is non-zero) or the size computed from src.size(), fx, and fy; the type of dst is the same as of src.
#
# The function has **2 required arguments**:
#
# 1. `src`:	input image
#
# 2. `dsize`: output image size
#
# Optional arguments that are often used include:
#
# 1. `fx`: Scale factor along the horizontal axis; when it equals 0, it is computed as (𝚍𝚘𝚞𝚋𝚕𝚎)𝚍𝚜𝚒𝚣𝚎.𝚠𝚒𝚍𝚝𝚑/𝚜𝚛𝚌.𝚌𝚘𝚕𝚜
#
# 2. `fy`: Scale factor along the vertical axis; when it equals 0, it is computed as (𝚍𝚘𝚞𝚋𝚕𝚎)𝚍𝚜𝚒𝚣𝚎.𝚑𝚎𝚒𝚐𝚑𝚝/𝚜𝚛𝚌.𝚛𝚘𝚠𝚜
#
# The output image has the size `dsize` (when it is non-zero) or the size computed from `src.size()`, `fx`, and `fy`; the type of dst is the same as of src.
#
# ### <font style="color:rgb(8,133,37)">OpenCV Documentation</font>
#
# **`resize()`**: <a href="https://docs.opencv.org/4.5.0/da/d54/group__imgproc__transform.html#ga47a974309e9102f5f08231edc7e7529d" target="_blank">Documentation link</a>

# %%
imgcroprgb=cv2.resize(imgcropped,None,fx=3,fy=3)
plt.imshow(imgcroprgb)

# %%
imgcroprgb2=cv2.resize(imgcropped,(100,200),interpolation=cv2.INTER_AREA)
plt.imshow(imgcroprgb2)

# %% [markdown]
# #Flipping images

# %%
flipimg=cv2.flip(imgcroprgb,0);plt.imshow(flipimg)

# %%
flipimg=cv2.flip(imgcroprgb,1);plt.imshow(flipimg)

# %%
flipimg=cv2.flip(imgcroprgb,-1);plt.imshow(flipimg)
